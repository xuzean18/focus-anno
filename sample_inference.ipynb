# %%
! pip install transformers

from transformers import DebertaForTokenClassification, DebertaTokenizerFast, BertForTokenClassification, BertTokenizerFast, RobertaForTokenClassification, RobertaTokenizerFast, pipeline
# Out:
# ...
# 2024-06-11 16:07:37.214626: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-11 16:07:37.214763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-11 16:07:37.358691: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
new_tokenizer = "/kaggle/input/deberta-tuned/tokenizer"
new_model = "/kaggle/input/deberta-tuned/model"

focus_classifier = pipeline(
    "token-classification", tokenizer=new_tokenizer, model=new_model, aggregation_strategy="simple"
)

sent1 = "Where did John hide? He hid behind the curtain."
sent2 = "Where did John hide? He hid behind the colorful curtain."
sent3 = "Where did John hide? He hid behind the colorful curtain, which makes it difficult to find him."
sent4 = "Did John hide behind this or that colorful curtain? He hid behind this colorful curtain."

print (focus_classifier(sent1))
print (focus_classifier(sent2))
print (focus_classifier(sent3))
print (focus_classifier(sent4))
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity_group': 'focus',
#   'score': 0.8801318,
#   'word': ' this',
#   'start': 65,
#   'end': 70}]
